# %%
# Initial exploration notebook for Phase 1
# Load data for a stock and visualize proxies vs price
import pandas as pd
import matplotlib.pyplot as plt
from features.data_ingestion.pipeline import build_dataset

df = build_dataset('TSLA')
plt.figure(figsize=(12,6))
plt.plot(df['Close'], label='Price')
if 'google_trends_ev' in df.columns:
    plt.plot(df['google_trends_ev'] * df['Close'].max() / df['google_trends_ev'].max(), label='Scaled Google Trends EV')
plt.legend()
plt.show()
